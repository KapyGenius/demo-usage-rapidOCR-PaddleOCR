# %%
# onnx models
# https://modelscope.cn/models/RapidAI/RapidOCR/files

# %%
from rapidocr_onnxruntime import RapidOCR

# %%
engine = RapidOCR(det_model_path="models/ocr_v4_det_server.onnx", rec_model_path="models/ocr_v4_rec_server.onnx")
img_url = "F921G4IIJX58MRB.LARGE_.jpg"

# %%
result = engine(img_url)

# %%
result
# Out:
# ([[[[178.0, 175.0], [473.0, 140.0], [476.0, 166.0], [181.0, 201.0]],
#    'WELCOME TO BEST BUY #321',
#    0.9404859691858292],
#   [[[240.0, 192.0], [430.0, 169.0], [433.0, 196.0], [243.0, 219.0]],
#    'NILES,IL 60714',
#    0.9414865672588348],
#   [[[254.0, 214.0], [420.0, 194.0], [423.0, 221.0], [257.0, 241.0]],
#    '(847)827-7110',
#    0.9464738368988037],
#   [[[225.0, 268.0], [448.0, 241.0], [451.0, 267.0], [228.0, 294.0]],
#    'Keep your receipt!',
#    0.9373384283648597],
#   [[[98.0, 436.0], [419.0, 397.0], [422.0, 423.0], [101.0, 462.0]],
#    'Val #：1487-3506-2583-3739',
#    0.9587217593193054],
#   [[[419.0, 445.0], [594.0, 424.0], [597.0, 450.0], [422.0, 471.0]],
#    '12:5500151124',
#    0.9799025792341965],
#   [[[104.0, 483.0], [377.0, 450.0], [380.0, 477.0], [108.0, 510.0]],
#    '0321006428511/17/10',
#    0.9979184771838941],
#   [[[534.0, 503.0], [604.0, 494.0], [608.0, 522.0], [537.0, 531.0]],
#    '15.99',
#    0.9963208436965942],
# ...

# %%
result
# Out:
# ([[[[181.0, 176.0], [469.0, 141.0], [473.0, 167.0], [184.0, 202.0]],
#    'WELCOME TO BEST BUY #321',
#    0.94615009923776],
#   [[[241.0, 193.0], [429.0, 171.0], [432.0, 198.0], [244.0, 220.0]],
#    'NILES,IL 60714',
#    0.9532302916049957],
#   [[[256.0, 215.0], [420.0, 196.0], [423.0, 223.0], [259.0, 242.0]],
#    '(847）827-7110',
#    0.939058794425084],
#   [[[227.0, 269.0], [447.0, 242.0], [451.0, 269.0], [230.0, 296.0]],
#    'Keep your receipt!',
#    0.9424645437134637],
#   [[[100.0, 437.0], [418.0, 399.0], [421.0, 425.0], [103.0, 463.0]],
#    'Val#：1487-3506-2583-3739',
#    0.9753149598836899],
#   [[[420.0, 446.0], [593.0, 425.0], [596.0, 452.0], [423.0, 473.0]],
#    '12:5500151124',
#    0.9764898373530462],
#   [[[106.0, 484.0], [377.0, 451.0], [380.0, 477.0], [110.0, 510.0]],
#    '0321006428511/17/10',
#    0.9976406881683751],
#   [[[534.0, 503.0], [604.0, 495.0], [607.0, 524.0], [538.0, 532.0]],
#    '15.99',
#    0.995917820930481],
# ...
